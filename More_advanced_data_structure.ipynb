# %% [markdown]
# <a href="https://colab.research.google.com/github/kanyaweeud/data_viz/blob/main/More_advanced_data_structure.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ที่เรียนไปแล้วมี 1 ตัวคือ list หน้าตาประมาณนี้
#
# ![arrays.png](data:image/png;base64,...)

# %% [markdown]
# # Dictionary
#
# สามารถ index ด้วยอะไรก็ได้ แต่ลำดับจะหายไป

# %%
ex_dict = {'a':10, '1':1, 'stat':5} #curly brackets ในการบอกว่าเป็น dict

# %%
ex_dict['stat']
# Out:
# 5

# %%
ex2_dict = {1:'one', 2:'two', 3:'three'}

# %%
ex2_dict[2]
# Out:
# 'two'

# %% [markdown]
# #### การเพิ่มสมาชิกใน dict

# %%
ex2_dict[0] = 'zero'

# %%
ex2_dict
# Out:
# {0: 'zero', 1: 'one', 2: 'two', 3: 'three'}

# %% [markdown]
# คำสั่ง

# %%
ex2_dict.keys()
# Out:
# dict_keys([1, 2, 3, 0])

# %%
for index in ex2_dict.keys():
    print(index)
# Out:
# 1
# 2
# 3
# 0

# %%
ex2_dict.values()
# Out:
# dict_values(['one', 'two', 'three', 'zero'])

# %%
index
# Out:
# 0

# %% [markdown]
# dict เอาไปใช้ร่วมกับ Dataframe ของ pandas

# %% [markdown]
# ##Numpy Array (array n มิติ)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# numpy คือ package ที่ทำงานเกี่ยวกับ array ของตัวเลข (ที่มีคนเขียนขึ้นมาและนิยมใช้)
#
# numpy -> number python

# %%
import numpy #วิธีเรียกใช้งาน package

# %% [markdown]
# ### สร้าง numpy array

# %%
ex_2d_array = numpy.array([[5.2,3.0,4.5],[9.1,0.1,0.3]])
print(ex_2d_array)
# Out:
# [[5.2 3.  4.5]
#  [9.1 0.1 0.3]]

# %% [markdown]
# ### การชี้ค่าใน numpy array

# %%
ex_2d_array[1,2]
# Out:
# 0.3

# %%
list_x = [[5.2,3.0,4.5],[9.1,0.1,0.3]] #การชี้ list

print(len(list_x))

print(list_x[1])

print(list_x[1][2])
# Out:
# 2
# [9.1, 0.1, 0.3]
# 0.3

# %% [markdown]
# ### Operations

# %%
ex2_2d_array = numpy.array([[1,0,0],[0,0,1]])
print(ex2_2d_array)
print(ex_2d_array)
# Out:
# [[1 0 0]
#  [0 0 1]]
# [[5.2 3.  4.5]
#  [9.1 0.1 0.3]]

# %%
ex_2d_array.shape #ตรวจสอบขนาดของ matrix
# Out:
# (2, 3)

# %%
ex_2d_array + ex2_2d_array
# Out:
# array([[6.2, 3. , 4.5],
#        [9.1, 0.1, 1.3]])

# %%
list_x = [[5.2,3.0,4.5],[9.1,0.1,0.3]] 
list_x2 = [[1,0,0],[0,0,1]]

list_x + list_x2
# Out:
# [[5.2, 3.0, 4.5], [9.1, 0.1, 0.3], [1, 0, 0], [0, 0, 1]]

# %%
ex_2d_array - ex2_2d_array
# Out:
# array([[ 4.2,  3. ,  4.5],
#        [ 9.1,  0.1, -0.7]])

# %%
ex_2d_array * ex2_2d_array #การคูณแบบ array เอาตำแหน่งเดียวกันมาคูณกัน
# Out:
# array([[5.2, 0. , 0. ],
#        [0. , 0. , 0.3]])

# %% [markdown]
# matix multiplication (dot product)
#
# ![matrix-multiply1.gif](data:image/gif;base64,...)

# %%
numpy.dot(ex_2d_array,ex2_2d_array) #คูณไม่ได้
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-233684682740> in <module>()
# ----> 1 numpy.dot(ex_2d_array,ex2_2d_array) #คูณแบบนี้ไม่ได้
#
# <__array_function__ internals> in dot(*args, **kwargs)
#
# ValueError: shapes (2,3) and (2,3) not aligned: 3 (dim 1) != 2 (dim 0)

# %%
print(ex_2d_array)
print(ex_2d_array.T)
# Out:
# [[5.2 3.  4.5]
#  [9.1 0.1 0.3]]
# [[5.2 9.1]
#  [3.  0.1]
#  [4.5 0.3]]

# %%
dot_mat = numpy.dot(ex_2d_array,ex2_2d_array.T)
print(dot_mat)
# Out:
# [[5.2 4.5]
#  [9.1 0.3]]

# %%
numpy.linalg.det(dot_mat)
# Out:
# -39.389999999999986

# %% [markdown]
# search google -> stackoverflow หรือ web ของ package สำหรับ operations อื่นๆ

# %% [markdown]
# ## matrix slicing

# %%
print(ex_2d_array)
# Out:
# [[5.2 3.  4.5]
#  [9.1 0.1 0.3]]

# %%
ex_2d_array[1,1:]

# %%
ex_2d_array[:,:2]

# %% [markdown]
# จบวันที่ 14 Jan 2021

# %% [markdown]
# HW 5 เขียน function คูณ matrix
#
# แล้ว test กับ matrix ขนาด
#
# - (2,3)*(3,2)
# - (4,4)*(4,1)
# - (2,2)*(2,2)

# %% [markdown]
# ## random, ones, zeros
