# %% [markdown]
# <a href="https://colab.research.google.com/github/kanyaweeud/data_viz/blob/main/Pandas_101.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

path = '/content/drive/My Drive/dataviz_2021_data'

# %%
covid_file_path = os.path.join(path,'pm-24-jan-2021.csv') 
print(covid_file_path)
# Out:
# /content/drive/My Drive/dataviz_2021_data/pm-24-jan-2021.csv

# %%
a = path + '/pm-24-jan-2021.csv' 
print(a)
# Out:
# /content/drive/My Drive/dataviz_2021_data/pm-24-jan-2021.csv

# %% [markdown]
# ## load data to memory

# %%
data_covid = pd.read_csv(covid_file_path)
data_covid
# Out:
#          No.  ...                                           risk
# 0          1  ...               คนต่างชาติเดินทางมาจากต่างประเทศ
# 1          2  ...               คนต่างชาติเดินทางมาจากต่างประเทศ
# 2          3  ...               คนต่างชาติเดินทางมาจากต่างประเทศ
# 3          4  ...               คนต่างชาติเดินทางมาจากต่างประเทศ
# 4          5  ...               คนต่างชาติเดินทางมาจากต่างประเทศ
# ...      ...  ...                                            ...
# 13495  13496  ...                                     ระบุไม่ได้
# 13496  13497  ...    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 13497  13498  ...    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 13498  13499  ...  ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว
# 13499  13500  ...    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
#
# [13500 rows x 10 columns]

# %%
data_covid.head()
# Out:
#    No. announce_date  ... district_of_onset                              risk
# 0    1     1/12/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 1    2     1/17/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2    3     1/22/2020  ...             เมือง  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3    4     1/22/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4    5     1/24/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
#
# [5 rows x 10 columns]

# %%
data_covid.shape
# Out:
# (13500, 10)

# %% [markdown]
# ## ชี้ค่าในตาราง

# %% [markdown]
# #### basic

# %%
data_covid['province_of_onset']
# Out:
# 0        กรุงเทพมหานคร
# 1        กรุงเทพมหานคร
# 2               นครปฐม
# 3        กรุงเทพมหานคร
# 4        กรุงเทพมหานคร
#              ...
# 13495    กรุงเทพมหานคร
# 13496    กรุงเทพมหานคร
# 13497    กรุงเทพมหานคร
# 13498    กรุงเทพมหานคร
# 13499    กรุงเทพมหานคร
# Name: province_of_onset, Length: 13500, dtype: object

# %%
data_covid['province_of_onset'][4]
# Out:
# 'กรุงเทพมหานคร'

# %% [markdown]
# #### .iloc

# %%
data_covid.iloc[4,7]
# Out:
# 'กรุงเทพมหานคร'

# %% [markdown]
# ## Table slicing

# %% [markdown]
# #### ตัดมาเฉพาะ column ที่ต้องการ

# %%
smaller_table = data_covid[['announce_date','province_of_onset','risk']]
smaller_table
# Out:
#       announce_date  ...                                           risk
# 0         1/12/2020  ...               คนต่างชาติเดินทางมาจากต่างประเทศ
# 1         1/17/2020  ...               คนต่างชาติเดินทางมาจากต่างประเทศ
# 2         1/22/2020  ...               คนต่างชาติเดินทางมาจากต่างประเทศ
# 3         1/22/2020  ...               คนต่างชาติเดินทางมาจากต่างประเทศ
# 4         1/24/2020  ...               คนต่างชาติเดินทางมาจากต่างประเทศ
# ...             ...  ...                                            ...
# 13495     1/24/2021  ...                                     ระบุไม่ได้
# 13496     1/24/2021  ...    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 13497     1/24/2021  ...    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 13498     1/24/2021  ...  ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว
# 13499     1/24/2021  ...    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
#
# [13500 rows x 3 columns]

# %% [markdown]
# #### ตัดเฉพาะ rows ที่ต้องการ

# %% [markdown]
# ##### แบบง่าย แต่ใช้การอะไรไม่ค่อยจะได้ (มองเป็น array แล้วตัดแบบ array)

# %%
data_covid.iloc[1:5,:]
# Out:
#    No. announce_date  ... district_of_onset                              risk
# 1    2     1/17/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2    3     1/22/2020  ...             เมือง  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3    4     1/22/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4    5     1/24/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
#
# [4 rows x 10 columns]

# %% [markdown]
# แบบ advanced แต่ใช้ประโยชน์ได้เยอะกว่า (ตัดแบบใช้ logic query)

# %%
data_covid[data_covid['province_of_onset']=='ขอนแก่น']
# Out:
#          No.  ...                                           risk
# 180      181  ...                                        สนามมวย
# 462      463  ...    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 1466    1467  ...                  คนไทยเดินทางกลับจากต่างประเทศ
# 1970    1971  ...  ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว
# 2637    2638  ...                  สัมผัสผู้เดินทางจากต่างประเทศ
# 2673    2674  ...    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 5948    5949  ...                              Cluster สมุทรสาคร
# 6082    6083  ...                              Cluster สมุทรสาคร
# 9333    9334  ...                           อยู่ระหว่างการสอบสวน
# 9334    9335  ...    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 10610  10611  ...    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 11517  11518  ...                           อยู่ระหว่างการสอบสวน
# 11697  11698  ...    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 11698  11699  ...    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
#
# [14 rows x 10 columns]

# %% [markdown]
# การชี้ค่าในตารางด้วย data_covid[***x***] ค่า ***x*** สามารถมีค่าที่ใส่เข้าไปได้ 2 แบบ
#
#
# 1.   ชื่อ column
# 2.   ใส่ rows ที่ต้องการ (ใส่ list ที่มีขนาดเท่ากับจำนวนแถว แล้วบอกว่าเอา แถวไหนบ้างโดยใช้ logical expression (```True```/```False```))

# %%
eight_rows_covid = data_covid.iloc[:8,:] # ตารางตัวอย่าง
eight_rows_covid
# Out:
#    No. announce_date  ... district_of_onset                              risk
# 0    1     1/12/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 1    2     1/17/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2    3     1/22/2020  ...             เมือง  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3    4     1/22/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4    5     1/24/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 5    6     1/25/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 6    7     1/26/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 7    8     1/26/2020  ...            หัวหิน  คนต่างชาติเดินทางมาจากต่างประเทศ
#
# [8 rows x 10 columns]

# %%
eight_rows_covid[[True,False,True,True,False,True,False,False]]   #2.   ใส่ rows ที่ต้องการ
# Out:
#    No. announce_date  ... district_of_onset                              risk
# 0    1     1/12/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2    3     1/22/2020  ...             เมือง  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3    4     1/22/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 5    6     1/25/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
#
# [4 rows x 10 columns]

# %%
eight_rows_covid['province_of_onset'] == 'กรุงเทพมหานคร'  #สร้าง list ของ logical expression
# Out:
# 0     True
# 1     True
# 2    False
# 3     True
# 4     True
# 5     True
# 6     True
# 7    False
# Name: province_of_onset, dtype: bool

# %%
eight_rows_covid[eight_rows_covid['province_of_onset'] == 'กรุงเทพมหานคร']  #เราเอา 2 บรรทัดบนมาบวกกัน
# Out:
#    No. announce_date  ... district_of_onset                              risk
# 0    1     1/12/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 1    2     1/17/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3    4     1/22/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4    5     1/24/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 5    6     1/25/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 6    7     1/26/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
#
# [6 rows x 10 columns]

# %% [markdown]
# HW (ให้ใช้เฉพาะที่อาจารย์สอนไปแล้วในวิชานี้)
#
# 1.   คำนวณ อายุเฉลี่ย ของผู้หญิง และผู้ชาย ของข้อมูลทั้งหมด
# 2.   คำนวณ อายุเฉลี่ย ของผู้หญิง และผู้ชาย ของผู้ป่วยในจังหวัดขอนแก่น

# %%
table = data_covid[['sex','age','province_of_onset']] 
sex0 = table[table['sex']=='ชาย']
age_m = sex0[['age']]
m = age_m.dropna()
mm = m.values

sum = 0
for i in mm :
     sum = float (sum + i)
     Mean_m = sum/len(mm)

# %%
sex1 = table[table['sex']=='หญิง']
age_w = sex1[['age']]
w = age_w.dropna()
ww = w.values

sum1 = 0
for i in ww :
     sum1 = float (sum1 + i)
     Mean_w = sum1/len(ww)

# %%
print(f'อายุเฉลี่ยของผู้หญิงทั้งหมด = {Mean_w} ปี')
print(f'อายุเฉลี่ยของผู้ชายทั้งหมด = {Mean_m} ปี')
# Out:
# อายุเฉลี่ยของผู้หญิงทั้งหมด = 36.694938854323105 ปี
# อายุเฉลี่ยของผู้ชายทั้งหมด = 39.20693583118001 ปี

# %%
KK = table[table['province_of_onset']=='ขอนแก่น']
sex00 = KK[KK['sex']=='ชาย']
KK_m = sex00[['age']]
KK_mm = KK_m.dropna()
mm2 = KK_mm.values

sum2 = 0
for i in mm2 :
     sum2 = float (sum2 + i)
     Mean_kkm = sum2/len(mm2) 

sex01 = KK[KK['sex']=='หญิง']
KK_w = sex01[['age']]
KK_ww = KK_w.dropna()
ww2 = KK_ww.values

sum02 = 0
for i in ww2 :
     sum02 = float (sum02 + i)
     Mean_kkw = sum02/len(ww2)

# %%
print(f'อายุเฉลี่ยผู้หญิงของผู้ป่วยในจังหวัดขอนแก่น = {Mean_kkw} ปี')
print(f'อายุเฉลี่ยผู้ชายของผู้ป่วยในจังหวัดขอนแก่น = {Mean_kkm} ปี')
# Out:
# อายุเฉลี่ยผู้หญิงของผู้ป่วยในจังหวัดขอนแก่น = 41.57142857142857 ปี
# อายุเฉลี่ยผู้ชายของผู้ป่วยในจังหวัดขอนแก่น = 26.571428571428573 ปี

# %% [markdown]
# 3. หาจำนวนผู้ป่วยที่เป็นคน "**คนต่างชาติเดินทางมาจากต่างประเทศ**"

# %%
data_covid[data_covid['risk'] == 'คนต่างชาติเดินทางมาจากต่างประเทศ'].shape[0]
# Out:
# 155

# %%
this_data = data_covid[['sex','age','province_of_onset']]

# %%
this_data
# Out:
#         sex   age province_of_onset
# 0      หญิง  61.0     กรุงเทพมหานคร
# 1      หญิง  74.0     กรุงเทพมหานคร
# 2      หญิง  73.0            นครปฐม
# 3       ชาย  68.0     กรุงเทพมหานคร
# 4      หญิง  66.0     กรุงเทพมหานคร
# ...     ...   ...               ...
# 13495  หญิง  49.0     กรุงเทพมหานคร
# 13496   ชาย  31.0     กรุงเทพมหานคร
# 13497   ชาย  45.0     กรุงเทพมหานคร
# 13498  หญิง  29.0     กรุงเทพมหานคร
# 13499  หญิง  44.0     กรุงเทพมหานคร
#
# [13500 rows x 3 columns]

# %%
female = this_data[this_data['sex']=='หญิง']
female['age']
# Out:
# 0        61.0
# 1        74.0
# 2        73.0
# 4        66.0
# 5        33.0
#          ...
# 13493    41.0
# 13494    33.0
# 13495    49.0
# 13498    29.0
# 13499    44.0
# Name: age, Length: 5571, dtype: float64

# %%
sum = 0
N = 0
for a in female['age']:
    
    if a > 0:
        sum += a # sum = sum + a
        N += 1

print(f'อายุเฉลี่ย ของ ผู้ป่วยหญิง {sum/N}')
# Out:
# อายุเฉลี่ย ของ ผู้ป่วยหญิง 36.694938854323105

# %%
female_KK = female[female['province_of_onset']=='ขอนแก่น']

sum = 0
N = 0
for a in female_KK['age']:
    
    if a > 0:
        sum += a # sum = sum + a
        N += 1

print(f'อายุเฉลี่ย ของ ผู้ป่วยหญิง ในจังหวัดขอนแก่น {sum/N}')
# Out:
# อายุเฉลี่ย ของ ผู้ป่วยหญิง ในจังหวัดขอนแก่น 41.57142857142857

# %% [markdown]
# การจัดการ Missing Value
#
# - ลบ record ที่เป็น missing
# - แทนที่ ค่า missing ด้วยค่าที่เหมาะสม mean, default, category-unknown
# - ใช้ ค่าจาก columns อื่นๆ ช่วยประมาณค่า ค่าใน column ที่หายไป (regression, deep learning, etc.)

# %% [markdown]
# ### ลบ record (dropna)
#
# missing = ```None``` ```NA```(not autorized) ```NaN``` (not a number)

# %%
this_data.shape #(12423, 3)
# Out:
# (13500, 3)

# %%
print(data_covid.shape)
print(data_covid.dropna().shape)
# Out:
# (13500, 10)
# (6914, 10)

# %%
this_data.dropna().shape
# Out:
# (8848, 3)

# %%
this_data.dropna()
# Out:
#         sex   age province_of_onset
# 0      หญิง  61.0     กรุงเทพมหานคร
# 1      หญิง  74.0     กรุงเทพมหานคร
# 2      หญิง  73.0            นครปฐม
# 3       ชาย  68.0     กรุงเทพมหานคร
# 4      หญิง  66.0     กรุงเทพมหานคร
# ...     ...   ...               ...
# 13495  หญิง  49.0     กรุงเทพมหานคร
# 13496   ชาย  31.0     กรุงเทพมหานคร
# 13497   ชาย  45.0     กรุงเทพมหานคร
# 13498  หญิง  29.0     กรุงเทพมหานคร
# 13499  หญิง  44.0     กรุงเทพมหานคร
#
# [8848 rows x 3 columns]

# %%
this_data.dropna()
print(this_data.shape)
# Out:
# (13500, 3)

# %%
this_data.dropna(inplace=True)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
this_data.dropna(inplace=True)
print(this_data.shape)
# Out:
# (8848, 3)
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
this_data = data_covid[['sex','age','province_of_onset']]
this_data.shape
# Out:
# (13500, 3)

# %%
this_data.dropna().shape
# Out:
# (8848, 3)

# %%
this_data.dropna(subset=['age']).shape
# Out:
# (9308, 3)

# %% [markdown]
# ### แทน missing ด้วยค่าที่เหมาะสม (```fillna```)

# %%
this_data = data_covid[['sex','age','province_of_onset']]

# %%
this_data.head()
# Out:
#     sex   age province_of_onset
# 0  หญิง  61.0     กรุงเทพมหานคร
# 1  หญิง  74.0     กรุงเทพมหานคร
# 2  หญิง  73.0            นครปฐม
# 3   ชาย  68.0     กรุงเทพมหานคร
# 4  หญิง  66.0     กรุงเทพมหานคร

# %%
print(f'จำนวน record ก่อน drop missing ใน province {this_data.shape[0]}')
print(f'จำนวน record หลัง drop missing ใน province {this_data.dropna(subset=["province_of_onset"]).shape[0]}')
# Out:
# จำนวน record ก่อน drop missing ใน province 13500
# จำนวน record หลัง drop missing ใน province 11454

# %%
this_data_updated = this_data.fillna(value={'sex':'ไม่รู้', 'age':-1, 'province_of_onset':'ไม่รู้'})
this_data_updated.head()
# Out:
#     sex   age province_of_onset
# 0  หญิง  61.0     กรุงเทพมหานคร
# 1  หญิง  74.0     กรุงเทพมหานคร
# 2  หญิง  73.0            นครปฐม
# 3   ชาย  68.0     กรุงเทพมหานคร
# 4  หญิง  66.0     กรุงเทพมหานคร

# %%
this_data_updated[this_data_updated['sex']=='ไม่รู้']
# Out:
#           sex  age province_of_onset
# 4391   ไม่รู้ -1.0         สมุทรสาคร
# 4392   ไม่รู้ -1.0         สมุทรสาคร
# 4393   ไม่รู้ -1.0         สมุทรสาคร
# 4394   ไม่รู้ -1.0         สมุทรสาคร
# 4395   ไม่รู้ -1.0         สมุทรสาคร
# ...       ...  ...               ...
# 13481  ไม่รู้ -1.0         สมุทรสาคร
# 13482  ไม่รู้ -1.0         สมุทรสาคร
# 13483  ไม่รู้ -1.0         สมุทรสาคร
# 13484  ไม่รู้ -1.0         สมุทรสาคร
# 13485  ไม่รู้ -1.0         สมุทรสาคร
#
# [2924 rows x 3 columns]

# %%
this_data_updated['province_of_onset']=='ไม่รู้'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 13495    False
# 13496    False
# 13497    False
# 13498    False
# 13499    False
# Name: province_of_onset, Length: 13500, dtype: bool

# %%
data_covid[this_data_updated['province_of_onset']=='ไม่รู้']
# Out:
#          No.  ...                                         risk
# 414      415  ...                                      สนามมวย
# 529      530  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 555      556  ...                                      สนามมวย
# 576      577  ...                                      สนามมวย
# 588      589  ...                         อยู่ระหว่างการสอบสวน
# ...      ...  ...                                          ...
# 13176  13177  ...                            Cluster สมุทรสาคร
# 13177  13178  ...                            Cluster สมุทรสาคร
# 13178  13179  ...                            Cluster สมุทรสาคร
# 13179  13180  ...                            Cluster สมุทรสาคร
# 13180  13181  ...                            Cluster สมุทรสาคร
#
# [2046 rows x 10 columns]

# %%
this_data_updated_2 = this_data.fillna(value={'province_of_onset':'ไม่รู้'})

# %%
this_data_updated_2[this_data_updated['sex']=='ไม่รู้']
# Out:
#        sex  age province_of_onset
# 4391   NaN  NaN         สมุทรสาคร
# 4392   NaN  NaN         สมุทรสาคร
# 4393   NaN  NaN         สมุทรสาคร
# 4394   NaN  NaN         สมุทรสาคร
# 4395   NaN  NaN         สมุทรสาคร
# ...    ...  ...               ...
# 13481  NaN  NaN         สมุทรสาคร
# 13482  NaN  NaN         สมุทรสาคร
# 13483  NaN  NaN         สมุทรสาคร
# 13484  NaN  NaN         สมุทรสาคร
# 13485  NaN  NaN         สมุทรสาคร
#
# [2924 rows x 3 columns]

# %% [markdown]
# ### การวนลูป record ในตาราง  (```iterrows```)

# %%
for each_row in this_data.iterrows():
    # print(each_row)
    # print(each_row[1])
    if (each_row[1]['age'] == 20) and (each_row[1]['province_of_onset'] == 'ขอนแก่น'):
        print(each_row)
# Out:
# (9334, sex                      ชาย
# age                       20
# province_of_onset    ขอนแก่น
# Name: 9334, dtype: object)

# %% [markdown]
# **Quiz**

# %%
for rowcolumn in range(data_covid.shape[0]) : 
     if  (data_covid.iloc[row,2] == '1/1/2021') :
        print(rowcolumn)
        print(data_covid.iloc[rowcolumn,:])
# Out:
# 7163
# No.                                   7164
# announce_date                     1/2/2021
# notification_date                 1/1/2021
# sex                                   หญิง
# age                                     26
# nationality                       Thailand
# province_of_isolation               ชัยนาท
# province_of_onset                   ชัยนาท
# district_of_onset                   สรรพยา
# risk                     Cluster สมุทรสาคร
# Name: 7163, dtype: object
# 7164
# No.                                                               7165
# announce_date                                                 1/2/2021
# notification_date                                             1/1/2021
# sex                                                                ชาย
# age                                                                 43
# nationality                                                   Thailand
# province_of_isolation                                           นครปฐม
# province_of_onset                                               นครปฐม
# district_of_onset                                                เมือง
# risk                     ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว
# Name: 7164, dtype: object
# 7165
# No.                                                               7166
# announce_date                                                 1/2/2021
# notification_date                                             1/1/2021
# sex                                                               หญิง
# age                                                                 46
# nationality                                                   Thailand
# province_of_isolation                                           นครปฐม
# province_of_onset                                               นครปฐม
# district_of_onset                                                เมือง
# risk                     ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว
# Name: 7165, dtype: object
# 7166
# No.                                                             7167
# announce_date                                               1/2/2021
# notification_date                                           1/1/2021
# sex                                                             หญิง
# age                                                                1
# nationality                                                 Thailand
# province_of_isolation                                     สุพรรณบุรี
# province_of_onset                                         สุพรรณบุรี
# district_of_onset                                         สองพี่น้อง
# risk                     สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# Name: 7166, dtype: object
# 7167
# No.                                                                  7168
# announce_date                                                    1/2/2021
# notification_date                                                1/1/2021
# sex                                                                   ชาย
# age                                                                    35
# nationality                                                         Burma
# province_of_isolation                                            ปทุมธานี
# province_of_onset                                                ปทุมธานี
# district_of_onset                                                  รังสิต
# risk                     การค้นหาผู้ป่วยเชิงรุกและค้นหาผู้ติดเชื้อในชุมชน
# Name: 7167, dtype: object
# 7168
# No.                                                                  7169
# announce_date                                                    1/2/2021
# notification_date                                                1/1/2021
# sex                                                                  หญิง
# age                                                                    28
# nationality                                                         Burma
# province_of_isolation                                                 ตาก
# province_of_onset                                                     ตาก
# district_of_onset                                                  แม่สอด
# risk                     การค้นหาผู้ป่วยเชิงรุกและค้นหาผู้ติดเชื้อในชุมชน
# Name: 7168, dtype: object
# 7169
# No.                                                             7170
# announce_date                                               1/2/2021
# notification_date                                           1/1/2021
# sex                                                             หญิง
# age                                                               41
# nationality                                                 Thailand
# province_of_isolation                                       ปทุมธานี
# province_of_onset                                           ปทุมธานี
# district_of_onset                                            ลำลูกกา
# risk                     สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# Name: 7169, dtype: object
# 7170
# No.                                                               7171
# announce_date                                                 1/2/2021
# notification_date                                             1/1/2021
# sex                                                               หญิง
# age                                                                 37
# nationality                                                   Thailand
# province_of_isolation                                         ปทุมธานี
# province_of_onset                                             ปทุมธานี
# district_of_onset                                             คลองหลวง
# risk                     ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว
# Name: 7170, dtype: object
# 7171
# No.                                                             7172
# announce_date                                               1/2/2021
# notification_date                                           1/1/2021
# sex                                                             หญิง
# age                                                               67
# nationality                                                 Thailand
# province_of_isolation                                        อ่างทอง
# province_of_onset                                            อ่างทอง
# district_of_onset                                              เมือง
# risk                     สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# Name: 7171, dtype: object
# 7172
# No.                                                             7173
# announce_date                                               1/2/2021
# notification_date                                           1/1/2021
# sex                                                              ชาย
# age                                                                8
# nationality                                                 Thailand
# province_of_isolation                                        อ่างทอง
# province_of_onset                                            อ่างทอง
# district_of_onset                                              เมือง
# risk                     สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# Name: 7172, dtype: object
# 7173
# No.                                          7174
# announce_date                            1/2/2021
# notification_date                        1/1/2021
# sex                                          หญิง
# age                                            32
# nationality                              Thailand
# province_of_isolation             พระนครศรีอยุธยา
# province_of_onset                 พระนครศรีอยุธยา
# district_of_onset                        บางปะอิน
# risk                     Cluster บ่อนพัทยา/ชลบุรี
# Name: 7173, dtype: object
# 7174
# No.                                                             7175
# announce_date                                               1/2/2021
# notification_date                                           1/1/2021
# sex                                                              ชาย
# age                                                               23
# nationality                                                 Thailand
# province_of_isolation                                  กรุงเทพมหานคร
# province_of_onset                                      กรุงเทพมหานคร
# district_of_onset                                               สาทร
# risk                     สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# Name: 7174, dtype: object
# 7175
# No.                                                             7176
# announce_date                                               1/2/2021
# notification_date                                           1/1/2021
# sex                                                             หญิง
# age                                                               33
# nationality                                                 Thailand
# province_of_isolation                                  กรุงเทพมหานคร
# province_of_onset                                      กรุงเทพมหานคร
# district_of_onset                                            ยานนาวา
# risk                     สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# Name: 7175, dtype: object
# 7176
# No.                                   7177
# announce_date                     1/2/2021
# notification_date                 1/1/2021
# sex                                   หญิง
# age                                     44
# nationality                       Thailand
# province_of_isolation              ราชบุรี
# province_of_onset                  ราชบุรี
# district_of_onset                    บางแพ
# risk                     Cluster สมุทรสาคร
# Name: 7176, dtype: object
# 7177
# No.                                                             7178
# announce_date                                               1/2/2021
# notification_date                                           1/1/2021
# sex                                                              ชาย
# age                                                               49
# nationality                                                 Thailand
# province_of_isolation                                  กรุงเทพมหานคร
# province_of_onset                                      กรุงเทพมหานคร
# district_of_onset                                            ยายนาวา
# risk                     สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# Name: 7177, dtype: object
# 7178
# No.                                   7179
# announce_date                     1/2/2021
# notification_date                 1/1/2021
# sex                                   หญิง
# age                                     31
# nationality                       Thailand
# province_of_isolation        กรุงเทพมหานคร
# province_of_onset            กรุงเทพมหานคร
# district_of_onset                 ทวีวัฒนา
# risk                     Cluster สมุทรสาคร
# Name: 7178, dtype: object
# 7179
# No.                                                             7180
# announce_date                                               1/2/2021
# notification_date                                           1/1/2021
# sex                                                              ชาย
# age                                                               27
# nationality                                                 Thailand
# province_of_isolation                                  กรุงเทพมหานคร
# province_of_onset                                            นนทบุรี
# district_of_onset                                             ้เมือง
# risk                     สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# Name: 7179, dtype: object
# 7180
# No.                                                             7181
# announce_date                                               1/2/2021
# notification_date                                           1/1/2021
# sex                                                              ชาย
# age                                                               26
# nationality                                                 Thailand
# province_of_isolation                                  กรุงเทพมหานคร
# province_of_onset                                      กรุงเทพมหานคร
# district_of_onset                                          คลองสามวา
# risk                     สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# Name: 7180, dtype: object
# 7181
# No.                                                             7182
# announce_date                                               1/2/2021
# notification_date                                           1/1/2021
# sex                                                              ชาย
# age                                                               35
# nationality                                                 Thailand
# province_of_isolation                                  กรุงเทพมหานคร
# province_of_onset                                      กรุงเทพมหานคร
# district_of_onset                                           ทวีวัฒนา
# risk                     สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# Name: 7181, dtype: object
# 7182
# No.                                                               7183
# announce_date                                                 1/2/2021
# notification_date                                             1/1/2021
# sex                                                                ชาย
# age                                                                 27
# nationality                                                   Pakistan
# province_of_isolation                                    กรุงเทพมหานคร
# province_of_onset                                        กรุงเทพมหานคร
# district_of_onset                                                พญาไท
# risk                     ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว
# Name: 7182, dtype: object
# 7183
# No.                                                             7184
# announce_date                                               1/2/2021
# notification_date                                           1/1/2021
# sex                                                             หญิง
# age                                                               24
# nationality                                                 Thailand
# province_of_isolation                                  กรุงเทพมหานคร
# province_of_onset                                      กรุงเทพมหานคร
# district_of_onset                                            ทุ่งครุ
# risk                     สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# Name: 7183, dtype: object
# 7184
# No.                                                             7185
# announce_date                                               1/2/2021
# notification_date                                           1/1/2021
# sex                                                              ชาย
# age                                                               61
# nationality                                                 Thailand
# province_of_isolation                                  กรุงเทพมหานคร
# province_of_onset                                      กรุงเทพมหานคร
# district_of_onset                                              ดุสิต
# risk                     สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# Name: 7184, dtype: object
# 7185
# No.                                                             7186
# announce_date                                               1/2/2021
# notification_date                                           1/1/2021
# sex                                                             หญิง
# age                                                               44
# nationality                                                 Thailand
# province_of_isolation                                  กรุงเทพมหานคร
# province_of_onset                                      กรุงเทพมหานคร
# district_of_onset                                            บึงกุ่ม
# risk                     สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# Name: 7185, dtype: object
# 7186
# No.                                                             7187
# announce_date                                               1/2/2021
# notification_date                                           1/1/2021
# sex                                                             หญิง
# age                                                               34
# nationality                                                    Burma
# province_of_isolation                                  กรุงเทพมหานคร
# province_of_onset                                      กรุงเทพมหานคร
# district_of_onset                                        บางขุนเทียน
# risk                     สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# Name: 7186, dtype: object
# 7187
# No.                                                             7188
# announce_date                                               1/2/2021
# notification_date                                           1/1/2021
# sex                                                              ชาย
# age                                                               28
# nationality                                                    Burma
# province_of_isolation                                  กรุงเทพมหานคร
# province_of_onset                                      กรุงเทพมหานคร
# district_of_onset                                       บางขุุนเทียน
# risk                     สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# Name: 7187, dtype: object
# 7188
# No.                                                             7189
# announce_date                                               1/2/2021
# notification_date                                           1/1/2021
# sex                                                             หญิง
# age                                                                8
# nationality                                                 Thailand
# province_of_isolation                                  กรุงเทพมหานคร
# province_of_onset                                            นนทบุรี
# district_of_onset                                          บางบัวทอง
# risk                     สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# Name: 7188, dtype: object
# 7189
# No.                                                               7190
# announce_date                                                 1/2/2021
# notification_date                                             1/1/2021
# sex                                                                ชาย
# age                                                                 24
# nationality                                                   Thailand
# province_of_isolation                                    กรุงเทพมหานคร
# province_of_onset                                        กรุงเทพมหานคร
# district_of_onset                                             ห้วยขวาง
# risk                     ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว
# Name: 7189, dtype: object
# 7190
# No.                               7191
# announce_date                 1/2/2021
# notification_date             1/1/2021
# sex                                ชาย
# age                                 60
# nationality                   Thailand
# province_of_isolation    กรุงเทพมหานคร
# province_of_onset        กรุงเทพมหานคร
# district_of_onset              บางพลัด
# risk                       สถานบันเทิง
# Name: 7190, dtype: object
# 7191
# No.                                                              7192
# announce_date                                                1/2/2021
# notification_date                                            1/1/2021
# sex                                                              หญิง
# age                                                                25
# nationality                                                  Thailand
# province_of_isolation                                   กรุงเทพมหานคร
# province_of_onset                                       กรุงเทพมหานคร
# district_of_onset                                               วัฒนา
# risk                     ผู้ที่เดินทางมาจากต่างประเทศ และเข้า ASQ/ALQ
# Name: 7191, dtype: object
# 7192
# No.                                                             7193
# announce_date                                               1/2/2021
# notification_date                                           1/1/2021
# sex                                                              ชาย
# age                                                               33
# nationality                                                    Burma
# province_of_isolation                                  กรุงเทพมหานคร
# province_of_onset                                      กรุงเทพมหานคร
# district_of_onset                                             จอมทอง
# risk                     สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# Name: 7192, dtype: object
# 7193
# No.                                                              7194
# announce_date                                                1/2/2021
# notification_date                                            1/1/2021
# sex                                                               ชาย
# age                                                                60
# nationality                                                     India
# province_of_isolation                                   กรุงเทพมหานคร
# province_of_onset                                       กรุงเทพมหานคร
# district_of_onset                                               วัฒนา
# risk                     ผู้ที่เดินทางมาจากต่างประเทศ และเข้า ASQ/ALQ
# Name: 7193, dtype: object
# 7194
# No.                               7195
# announce_date                 1/2/2021
# notification_date             1/1/2021
# sex                               หญิง
# age                                 68
# nationality                   Thailand
# province_of_isolation    กรุงเทพมหานคร
# province_of_onset        กรุงเทพมหานคร
# district_of_onset            ภาษีเจริญ
# risk                     Cluster ระยอง
# Name: 7194, dtype: object
# 7195
# No.                          7196
# announce_date            1/2/2021
# notification_date        1/1/2021
# sex                          หญิง
# age                            44
# nationality                 Burma
# province_of_isolation     นนทบุรี
# province_of_onset         นนทบุรี
# district_of_onset         บางใหญ่
# risk                          NaN
# Name: 7195, dtype: object
# 7196
# No.                                                               7197
# announce_date                                                 1/2/2021
# notification_date                                             1/1/2021
# sex                                                               หญิง
# age                                                                 66
# nationality                                                   Thailand
# province_of_isolation                                          นนทบุรี
# province_of_onset                                              นนทบุรี
# district_of_onset                                             บางใหญ่่
# risk                     ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว
# Name: 7196, dtype: object
# 7197
# No.                                                               7198
# announce_date                                                 1/2/2021
# notification_date                                             1/1/2021
# sex                                                                ชาย
# age                                                                 37
# nationality                                                   Thailand
# province_of_isolation                                          นนทบุรี
# province_of_onset                                              นนทบุรี
# district_of_onset                                              บางใหญ่
# risk                     ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว
# Name: 7197, dtype: object
# 7198
# No.                                                               7199
# announce_date                                                 1/2/2021
# notification_date                                             1/1/2021
# sex                                                                ชาย
# age                                                                 56
# nationality                                                   Thailand
# province_of_isolation                                          นนทบุรี
# province_of_onset                                              นนทบุรี
# district_of_onset                                              บางใหญ่
# risk                     ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว
# Name: 7198, dtype: object
# 7199
# No.                                      7200
# announce_date                        1/2/2021
# notification_date                    1/1/2021
# sex                                       ชาย
# age                                        30
# nationality                          Thailand
# province_of_isolation                 นนทบุรี
# province_of_onset                     นนทบุรี
# district_of_onset                   บางบัวทอง
# risk                     อยู่ระหว่างการสอบสวน
# Name: 7199, dtype: object
# 7200
# No.                          7201
# announce_date            1/2/2021
# notification_date        1/1/2021
# sex                           ชาย
# age                            25
# nationality              Cambodia
# province_of_isolation     นนทบุรี
# province_of_onset         นนทบุรี
# district_of_onset         บางใหญ่
# risk                          NaN
# Name: 7200, dtype: object
# 7201
# No.                                                             7202
# announce_date                                               1/2/2021
# notification_date                                           1/1/2021
# sex                                                              ชาย
# age                                                               64
# nationality                                                 Thailand
# province_of_isolation                                        นนทบุรี
# province_of_onset                                            นนทบุรี
# district_of_onset                                            นนทบุรี
# risk                     สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# Name: 7201, dtype: object
# 7202
# No.                                                             7203
# announce_date                                               1/2/2021
# notification_date                                           1/1/2021
# sex                                                             หญิง
# age                                                               59
# nationality                                                 Thailand
# province_of_isolation                                        นนทบุรี
# province_of_onset                                            นนทบุรี
# district_of_onset                                          บางบัวทอง
# risk                     สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# Name: 7202, dtype: object
# 7203
# No.                                                             7204
# announce_date                                               1/2/2021
# notification_date                                           1/1/2021
# sex                                                              ชาย
# age                                                               44
# nationality                                                    Burma
# province_of_isolation                                        นนทบุรี
# province_of_onset                                            นนทบุรี
# district_of_onset                                            บางใหญ่
# risk                     สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# Name: 7203, dtype: object
# 7204
# No.                          7205
# announce_date            1/2/2021
# notification_date        1/1/2021
# sex                           NaN
# age                           NaN
# nationality                   NaN
# province_of_isolation     นนทบุรี
# province_of_onset             NaN
# district_of_onset             NaN
# risk                          NaN
# Name: 7204, dtype: object
# 7205
# No.                          7206
# announce_date            1/2/2021
# notification_date        1/1/2021
# sex                           NaN
# age                           NaN
# nationality                   NaN
# province_of_isolation     นนทบุรี
# province_of_onset             NaN
# district_of_onset             NaN
# risk                          NaN
# Name: 7205, dtype: object
# 7206
# No.                          7207
# announce_date            1/2/2021
# notification_date        1/1/2021
# sex                           NaN
# age                           NaN
# nationality                   NaN
# province_of_isolation     นนทบุรี
# province_of_onset             NaN
# district_of_onset             NaN
# risk                          NaN
# Name: 7206, dtype: object
# 7207
# No.                          7208
# announce_date            1/2/2021
# notification_date        1/1/2021
# sex                           NaN
# age                           NaN
# nationality                   NaN
# province_of_isolation     นนทบุรี
# province_of_onset             NaN
# district_of_onset             NaN
# risk                          NaN
# Name: 7207, dtype: object
# 7208
# No.                          7209
# announce_date            1/2/2021
# notification_date        1/1/2021
# sex                           NaN
# age                           NaN
# nationality                   NaN
# province_of_isolation     นนทบุรี
# province_of_onset             NaN
# district_of_onset             NaN
# risk                          NaN
# Name: 7208, dtype: object
# 7209
# No.                          7210
# announce_date            1/2/2021
# notification_date        1/1/2021
# sex                           NaN
# age                           NaN
# nationality                   NaN
# province_of_isolation     นนทบุรี
# province_of_onset             NaN
# district_of_onset             NaN
# risk                          NaN
# Name: 7209, dtype: object
# 7210
# No.                          7211
# announce_date            1/2/2021
# notification_date        1/1/2021
# sex                           NaN
# age                           NaN
# nationality                   NaN
# province_of_isolation     นนทบุรี
# province_of_onset             NaN
# district_of_onset             NaN
# risk                          NaN
# Name: 7210, dtype: object
# 7211
# No.                          7212
# announce_date            1/2/2021
# notification_date        1/1/2021
# sex                           NaN
# age                           NaN
# nationality                   NaN
# province_of_isolation     นนทบุรี
# province_of_onset             NaN
# district_of_onset             NaN
# risk                          NaN
# Name: 7211, dtype: object
# 7212
# No.                          7213
# announce_date            1/2/2021
# notification_date        1/1/2021
# sex                           NaN
# age                           NaN
# nationality                   NaN
# province_of_isolation     นนทบุรี
# province_of_onset             NaN
# district_of_onset             NaN
# risk                          NaN
# Name: 7212, dtype: object
# 7213
# No.                          7214
# announce_date            1/2/2021
# notification_date        1/1/2021
# sex                           NaN
# age                           NaN
# nationality                   NaN
# province_of_isolation     นนทบุรี
# province_of_onset             NaN
# district_of_onset             NaN
# risk                          NaN
# Name: 7213, dtype: object
# 7214
# No.                          7215
# announce_date            1/2/2021
# notification_date        1/1/2021
# sex                           NaN
# age                           NaN
# nationality                   NaN
# province_of_isolation     นนทบุรี
# province_of_onset             NaN
# district_of_onset             NaN
# risk                          NaN
# Name: 7214, dtype: object
# 7215
# No.                          7216
# announce_date            1/2/2021
# notification_date        1/1/2021
# sex                           NaN
# age                           NaN
# nationality                   NaN
# province_of_isolation     นนทบุรี
# province_of_onset             NaN
# district_of_onset             NaN
# risk                          NaN
# Name: 7215, dtype: object
# 7216
# No.                          7217
# announce_date            1/2/2021
# notification_date        1/1/2021
# sex                           NaN
# age                           NaN
# nationality                   NaN
# province_of_isolation     นนทบุรี
# province_of_onset             NaN
# district_of_onset             NaN
# risk                          NaN
# Name: 7216, dtype: object
# 7217
# No.                          7218
# announce_date            1/2/2021
# notification_date        1/1/2021
# sex                           NaN
# age                           NaN
# nationality                   NaN
# province_of_isolation     นนทบุรี
# province_of_onset             NaN
# district_of_onset             NaN
# risk                          NaN
# Name: 7217, dtype: object
# 7218
# No.                          7219
# announce_date            1/2/2021
# notification_date        1/1/2021
# sex                           NaN
# age                           NaN
# nationality                   NaN
# province_of_isolation     นนทบุรี
# province_of_onset             NaN
# district_of_onset             NaN
# risk                          NaN
# Name: 7218, dtype: object
# 7219
# No.                          7220
# announce_date            1/2/2021
# notification_date        1/1/2021
# sex                           NaN
# age                           NaN
# nationality                   NaN
# province_of_isolation     นนทบุรี
# province_of_onset             NaN
# district_of_onset             NaN
# risk                          NaN
# Name: 7219, dtype: object
# 7220
# No.                           7221
# announce_date             1/2/2021
# notification_date         1/1/2021
# sex                           หญิง
# age                             37
# nationality               Thailand
# province_of_isolation    สมุทรสาคร
# province_of_onset              NaN
# district_of_onset              NaN
# risk                           NaN
# Name: 7220, dtype: object
# 7221
# No.                           7222
# announce_date             1/2/2021
# notification_date         1/1/2021
# sex                            ชาย
# age                             47
# nationality               Thailand
# province_of_isolation    สมุทรสาคร
# province_of_onset              NaN
# district_of_onset              NaN
# risk                           NaN
# Name: 7221, dtype: object
# 7222
# No.                           7223
# announce_date             1/2/2021
# notification_date         1/1/2021
# sex                           หญิง
# age                             36
# nationality                  Burma
# province_of_isolation    สมุทรสาคร
# province_of_onset              NaN
# district_of_onset              NaN
# risk                           NaN
# Name: 7222, dtype: object
# 7223
# No.                           7224
# announce_date             1/2/2021
# notification_date         1/1/2021
# sex                           หญิง
# age                             22
# nationality                  Burma
# province_of_isolation    สมุทรสาคร
# province_of_onset              NaN
# district_of_onset              NaN
# risk                           NaN
# Name: 7223, dtype: object
# 7224
# No.                           7225
# announce_date             1/2/2021
# notification_date         1/1/2021
# sex                           หญิง
# age                             21
# nationality                  Burma
# province_of_isolation    สมุทรสาคร
# province_of_onset              NaN
# district_of_onset              NaN
# risk                           NaN
# Name: 7224, dtype: object
# 7225
# No.                           7226
# announce_date             1/2/2021
# notification_date         1/1/2021
# sex                           หญิง
# age                             28
# nationality                  Burma
# province_of_isolation    สมุทรสาคร
# province_of_onset              NaN
# district_of_onset              NaN
# risk                           NaN
# Name: 7225, dtype: object
# 7226
# No.                           7227
# announce_date             1/2/2021
# notification_date         1/1/2021
# sex                           หญิง
# age                             27
# nationality                  Burma
# province_of_isolation    สมุทรสาคร
# province_of_onset              NaN
# district_of_onset              NaN
# risk                           NaN
# Name: 7226, dtype: object
# 7227
# No.                           7228
# announce_date             1/2/2021
# notification_date         1/1/2021
# sex                           หญิง
# age                             26
# nationality                  Burma
# province_of_isolation    สมุทรสาคร
# province_of_onset              NaN
# district_of_onset              NaN
# risk                           NaN
# Name: 7227, dtype: object
# 7228
# No.                           7229
# announce_date             1/2/2021
# notification_date         1/1/2021
# sex                            ชาย
# age                             19
# nationality                  Burma
# province_of_isolation    สมุทรสาคร
# province_of_onset              NaN
# district_of_onset              NaN
# risk                           NaN
# Name: 7228, dtype: object
# 7229
# No.                           7230
# announce_date             1/2/2021
# notification_date         1/1/2021
# sex                           หญิง
# age                             20
# nationality                  Burma
# province_of_isolation    สมุทรสาคร
# province_of_onset              NaN
# district_of_onset              NaN
# risk                           NaN
# Name: 7229, dtype: object
# 7230
# No.                           7231
# announce_date             1/2/2021
# notification_date         1/1/2021
# sex                            ชาย
# age                             36
# nationality                  Burma
# province_of_isolation    สมุทรสาคร
# province_of_onset              NaN
# district_of_onset              NaN
# risk                           NaN
# Name: 7230, dtype: object
# 7231
# No.                           7232
# announce_date             1/2/2021
# notification_date         1/1/2021
# sex                           หญิง
# age                             26
# nationality                  Burma
# province_of_isolation    สมุทรสาคร
# province_of_onset              NaN
# district_of_onset              NaN
# risk                           NaN
# Name: 7231, dtype: object
# 7232
# No.                           7233
# announce_date             1/2/2021
# notification_date         1/1/2021
# sex                           หญิง
# age                             19
# nationality                  Burma
# province_of_isolation    สมุทรสาคร
# province_of_onset              NaN
# district_of_onset              NaN
# risk                           NaN
# Name: 7232, dtype: object
# 7233
# No.                           7234
# announce_date             1/2/2021
# notification_date         1/1/2021
# sex                           หญิง
# age                             44
# nationality                  Burma
# province_of_isolation    สมุทรสาคร
# province_of_onset              NaN
# district_of_onset              NaN
# risk                           NaN
# Name: 7233, dtype: object
# 7234
# No.                           7235
# announce_date             1/2/2021
# notification_date         1/1/2021
# sex                           หญิง
# age                             49
# nationality                  Burma
# province_of_isolation    สมุทรสาคร
# province_of_onset              NaN
# district_of_onset              NaN
# risk                           NaN
# Name: 7234, dtype: object
# 7235
# No.                           7236
# announce_date             1/2/2021
# notification_date         1/1/2021
# sex                           หญิง
# age                             24
# nationality                  Burma
# province_of_isolation    สมุทรสาคร
# province_of_onset              NaN
# district_of_onset              NaN
# risk                           NaN
# Name: 7235, dtype: object
# 7236
# No.                           7237
# announce_date             1/2/2021
# notification_date         1/1/2021
# sex                           หญิง
# age                             21
# nationality                  Burma
# province_of_isolation    สมุทรสาคร
# province_of_onset              NaN
# district_of_onset              NaN
# risk                           NaN
# Name: 7236, dtype: object
# 7237
# No.                           7238
# announce_date             1/2/2021
# notification_date         1/1/2021
# sex                            ชาย
# age                             32
# nationality                  Burma
# province_of_isolation    สมุทรสาคร
# province_of_onset              NaN
# district_of_onset              NaN
# risk                           NaN
# Name: 7237, dtype: object
# 7238
# No.                           7239
# announce_date             1/2/2021
# notification_date         1/1/2021
# sex                           หญิง
# age                             25
# nationality                  Burma
# province_of_isolation    สมุทรสาคร
# province_of_onset              NaN
# district_of_onset              NaN
# risk                           NaN
# Name: 7238, dtype: object
# 7239
# No.                           7240
# announce_date             1/2/2021
# notification_date         1/1/2021
# sex                           หญิง
# age                             23
# nationality                  Burma
# province_of_isolation    สมุทรสาคร
# province_of_onset              NaN
# district_of_onset              NaN
# risk                           NaN
# Name: 7239, dtype: object
# 7240
# No.                           7241
# announce_date             1/2/2021
# notification_date         1/1/2021
# sex                           หญิง
# age                             32
# nationality                  Burma
# province_of_isolation    สมุทรสาคร
# province_of_onset              NaN
# district_of_onset              NaN
# risk                           NaN
# Name: 7240, dtype: object
# 7241
# No.                           7242
# announce_date             1/2/2021
# notification_date         1/1/2021
# sex                           หญิง
# age                             25
# nationality                  Burma
# province_of_isolation    สมุทรสาคร
# province_of_onset              NaN
# district_of_onset              NaN
# risk                           NaN
# Name: 7241, dtype: object
# 7242
# No.                           7243
# announce_date             1/2/2021
# notification_date         1/1/2021
# sex                            ชาย
# age                             72
# nationality               Thailand
# province_of_isolation    สมุทรสาคร
# province_of_onset              NaN
# district_of_onset              NaN
# risk                           NaN
# Name: 7242, dtype: object
# 7243
# No.                           7244
# announce_date             1/2/2021
# notification_date         1/1/2021
# sex                           หญิง
# age                             49
# nationality               Thailand
# province_of_isolation    สมุทรสาคร
# province_of_onset              NaN
# district_of_onset              NaN
# risk                           NaN
# Name: 7243, dtype: object
# 7244
# No.                           7245
# announce_date             1/2/2021
# notification_date         1/1/2021
# sex                           หญิง
# age                             40
# nationality                  Burma
# province_of_isolation    สมุทรสาคร
# province_of_onset              NaN
# district_of_onset              NaN
# risk                           NaN
# Name: 7244, dtype: object
# 7245
# No.                           7246
# announce_date             1/2/2021
# notification_date         1/1/2021
# sex                            ชาย
# age                             38
# nationality                  Burma
# province_of_isolation    สมุทรสาคร
# province_of_onset              NaN
# district_of_onset              NaN
# risk                           NaN
# Name: 7245, dtype: object
# 7246
# No.                           7247
# announce_date             1/2/2021
# notification_date         1/1/2021
# sex                           หญิง
# age                             38
# nationality                  Burma
# province_of_isolation    สมุทรสาคร
# province_of_onset              NaN
# district_of_onset              NaN
# risk                           NaN
# Name: 7246, dtype: object
# 7247
# No.                           7248
# announce_date             1/2/2021
# notification_date         1/1/2021
# sex                            ชาย
# age                             54
# nationality                  Burma
# province_of_isolation    สมุทรสาคร
# province_of_onset              NaN
# district_of_onset              NaN
# risk                           NaN
# Name: 7247, dtype: object
# 7248
# No.                           7249
# announce_date             1/2/2021
# notification_date         1/1/2021
# sex                           หญิง
# age                             41
# nationality                  Burma
# province_of_isolation    สมุทรสาคร
# province_of_onset              NaN
# district_of_onset              NaN
# risk                           NaN
# Name: 7248, dtype: object
# 7249
# No.                           7250
# announce_date             1/2/2021
# notification_date         1/1/2021
# sex                           หญิง
# age                             42
# nationality                  Burma
# province_of_isolation    สมุทรสาคร
# province_of_onset              NaN
# district_of_onset              NaN
# risk                           NaN
# Name: 7249, dtype: object
# 7250
# No.                           7251
# announce_date             1/2/2021
# notification_date         1/1/2021
# sex                            ชาย
# age                             26
# nationality                  Burma
# province_of_isolation    สมุทรสาคร
# province_of_onset              NaN
# district_of_onset              NaN
# risk                           NaN
# Name: 7250, dtype: object
# 7251
# No.                           7252
# announce_date             1/2/2021
# notification_date         1/1/2021
# sex                           หญิง
# age                             30
# nationality                  Burma
# province_of_isolation    สมุทรสาคร
# province_of_onset              NaN
# district_of_onset              NaN
# risk                           NaN
# Name: 7251, dtype: object
# 7252
# No.                           7253
# announce_date             1/2/2021
# notification_date         1/1/2021
# sex                           หญิง
# age                             25
# nationality                  Burma
# province_of_isolation    สมุทรสาคร
# province_of_onset              NaN
# district_of_onset              NaN
# risk                           NaN
# Name: 7252, dtype: object
# 7253
# No.                           7254
# announce_date             1/2/2021
# notification_date         1/1/2021
# sex                           หญิง
# age                             32
# nationality               Thailand
# province_of_isolation    สมุทรสาคร
# province_of_onset              NaN
# district_of_onset              NaN
# risk                           NaN
# Name: 7253, dtype: object
# 7254
# No.                           7255
# announce_date             1/2/2021
# notification_date         1/1/2021
# sex                           หญิง
# age                             20
# nationality               Thailand
# province_of_isolation    สมุทรสาคร
# province_of_onset              NaN
# district_of_onset              NaN
# risk                           NaN
# Name: 7254, dtype: object
# 7255
# No.                           7256
# announce_date             1/2/2021
# notification_date         1/1/2021
# sex                           หญิง
# age                             64
# nationality               Thailand
# province_of_isolation    สมุทรสาคร
# province_of_onset              NaN
# district_of_onset              NaN
# risk                           NaN
# Name: 7255, dtype: object
# 7256
# No.                           7257
# announce_date             1/2/2021
# notification_date         1/1/2021
# sex                           หญิง
# age                             54
# nationality               Thailand
# province_of_isolation    สมุทรสาคร
# province_of_onset              NaN
# district_of_onset              NaN
# risk                           NaN
# Name: 7256, dtype: object
# 7257
# No.                           7258
# announce_date             1/2/2021
# notification_date         1/1/2021
# sex                            ชาย
# age                             27
# nationality                  Burma
# province_of_isolation    สมุทรสาคร
# province_of_onset              NaN
# district_of_onset              NaN
# risk                           NaN
# Name: 7257, dtype: object
# 7258
# No.                           7259
# announce_date             1/2/2021
# notification_date         1/1/2021
# sex                            ชาย
# age                             27
# nationality                  Burma
# ...
# risk                     อาชีพเสี่ยง เช่น ทำงานในสถานที่แออัด หรือทำงาน...
# Name: 7354, dtype: object
# 7355
# No.                                                                   7356
# announce_date                                                     1/2/2021
# notification_date                                                 1/1/2021
# sex                                                                    ชาย
# age                                                                     37
# nationality                                                       Cambodia
# province_of_isolation                                          สมุทรปราการ
# province_of_onset                                              สมุทรปราการ
# district_of_onset                                                   บางพลี
# risk                     อาชีพเสี่ยง เช่น ทำงานในสถานที่แออัด หรือทำงาน...
# Name: 7355, dtype: object
# 7356
# No.                                                                   7357
# announce_date                                                     1/2/2021
# notification_date                                                 1/1/2021
# sex                                                                    ชาย
# age                                                                     41
# nationality                                                       Cambodia
# province_of_isolation                                          สมุทรปราการ
# province_of_onset                                              สมุทรปราการ
# district_of_onset                                                   บางพลี
# risk                     อาชีพเสี่ยง เช่น ทำงานในสถานที่แออัด หรือทำงาน...
# Name: 7356, dtype: object
# 7357
# No.                                                                   7358
# announce_date                                                     1/2/2021
# notification_date                                                 1/1/2021
# sex                                                                    ชาย
# age                                                                     26
# nationality                                                          Burma
# province_of_isolation                                          สมุทรปราการ
# province_of_onset                                              สมุทรปราการ
# district_of_onset                                                   บางพลี
# risk                     อาชีพเสี่ยง เช่น ทำงานในสถานที่แออัด หรือทำงาน...
# Name: 7357, dtype: object
# 7358
# No.                                                                   7359
# announce_date                                                     1/2/2021
# notification_date                                                 1/1/2021
# sex                                                                   หญิง
# age                                                                     25
# nationality                                                       Cambodia
# province_of_isolation                                          สมุทรปราการ
# province_of_onset                                              สมุทรปราการ
# district_of_onset                                                   บางพลี
# risk                     อาชีพเสี่ยง เช่น ทำงานในสถานที่แออัด หรือทำงาน...
# Name: 7358, dtype: object
# 7359
# No.                                                             7360
# announce_date                                               1/2/2021
# notification_date                                           1/1/2021
# sex                                                             หญิง
# age                                                               56
# nationality                                                 Thailand
# province_of_isolation                                    สมุทรปราการ
# province_of_onset                                        สมุทรปราการ
# district_of_onset                                     พระสมุทรเจดีย์
# risk                     สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# Name: 7359, dtype: object
# 7360
# No.                                                             7361
# announce_date                                               1/2/2021
# notification_date                                           1/1/2021
# sex                                                             หญิง
# age                                                               58
# nationality                                                 Thailand
# province_of_isolation                                    สมุทรปราการ
# province_of_onset                                        สมุทรปราการ
# district_of_onset                                     พระสมุทรเจดีย์
# risk                     สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# Name: 7360, dtype: object
# 7361
# No.                                                             7362
# announce_date                                               1/2/2021
# notification_date                                           1/1/2021
# sex                                                             หญิง
# age                                                               26
# nationality                                                 Thailand
# province_of_isolation                                    สมุทรปราการ
# province_of_onset                                        สมุทรปราการ
# district_of_onset                                     พระสมุทรเจดีย์
# risk                     สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# Name: 7361, dtype: object
# 7362
# No.                                                             7363
# announce_date                                               1/2/2021
# notification_date                                           1/1/2021
# sex                                                             หญิง
# age                                                               11
# nationality                                                 Thailand
# province_of_isolation                                    สมุทรปราการ
# province_of_onset                                        สมุทรปราการ
# district_of_onset                                     พระสมุทรเจดีย์
# risk                     สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# Name: 7362, dtype: object
# 7363
# No.                                                             7364
# announce_date                                               1/2/2021
# notification_date                                           1/1/2021
# sex                                                             หญิง
# age                                                               58
# nationality                                                 Thailand
# province_of_isolation                                    สมุทรปราการ
# province_of_onset                                        สมุทรปราการ
# district_of_onset                                     พระสมุทรเจดีย์
# risk                     สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# Name: 7363, dtype: object
# 7364
# No.                                                             7365
# announce_date                                               1/2/2021
# notification_date                                           1/1/2021
# sex                                                             หญิง
# age                                                               13
# nationality                                                 Thailand
# province_of_isolation                                    สมุทรปราการ
# province_of_onset                                        สมุทรปราการ
# district_of_onset                                     พระสมุทรเจดีย์
# risk                     สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# Name: 7364, dtype: object
# 7365
# No.                                                             7366
# announce_date                                               1/2/2021
# notification_date                                           1/1/2021
# sex                                                              ชาย
# age                                                               25
# nationality                                                 Thailand
# province_of_isolation                                    สมุทรปราการ
# province_of_onset                                      กรุงเทพมหานคร
# district_of_onset                                       เขตคลองสามวา
# risk                     สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# Name: 7365, dtype: object
# 7366
# No.                                                                   7367
# announce_date                                                     1/2/2021
# notification_date                                                 1/1/2021
# sex                                                                   หญิง
# age                                                                     43
# nationality                                                       Thailand
# province_of_isolation                                          สมุทรปราการ
# province_of_onset                                              สมุทรปราการ
# district_of_onset                                                 บางเสาธง
# risk                     อาชีพเสี่ยง เช่น ทำงานในสถานที่แออัด หรือทำงาน...
# Name: 7366, dtype: object
# 7367
# No.                                                                   7368
# announce_date                                                     1/2/2021
# notification_date                                                 1/1/2021
# sex                                                                   หญิง
# age                                                                     26
# nationality                                                       Thailand
# province_of_isolation                                          สมุทรปราการ
# province_of_onset                                              สมุทรปราการ
# district_of_onset                                                   บางพลี
# risk                     อาชีพเสี่ยง เช่น ทำงานในสถานที่แออัด หรือทำงาน...
# Name: 7367, dtype: object
# 7368
# No.                                                                   7369
# announce_date                                                     1/2/2021
# notification_date                                                 1/1/2021
# sex                                                                   หญิง
# age                                                                     26
# nationality                                                       Thailand
# province_of_isolation                                          สมุทรปราการ
# province_of_onset                                              สมุทรปราการ
# district_of_onset                                                   บางพลี
# risk                     อาชีพเสี่ยง เช่น ทำงานในสถานที่แออัด หรือทำงาน...
# Name: 7368, dtype: object
# 7369
# No.                          7370
# announce_date            1/2/2021
# notification_date        1/1/2021
# sex                          หญิง
# age                            41
# nationality              Thailand
# province_of_isolation    จันทบุรี
# province_of_onset        จันทบุรี
# district_of_onset           มะชาม
# risk                          NaN
# Name: 7369, dtype: object
# 7370
# No.                               7371
# announce_date                 1/2/2021
# notification_date             1/1/2021
# sex                               หญิง
# age                                 45
# nationality                   Thailand
# province_of_isolation         จันทบุรี
# province_of_onset             จันทบุรี
# district_of_onset                เมือง
# risk                     Cluster ระยอง
# Name: 7370, dtype: object
# 7371
# No.                               7372
# announce_date                 1/2/2021
# notification_date             1/1/2021
# sex                               หญิง
# age                                 65
# nationality                   Thailand
# province_of_isolation         จันทบุรี
# province_of_onset             จันทบุรี
# district_of_onset                เมือง
# risk                     Cluster ระยอง
# Name: 7371, dtype: object
# 7372
# No.                           7373
# announce_date             1/2/2021
# notification_date         1/1/2021
# sex                            ชาย
# age                             50
# nationality               Thailand
# province_of_isolation     จันทบุรี
# province_of_onset         จันทบุรี
# district_of_onset        เขาคิชกุฏ
# risk                           NaN
# Name: 7372, dtype: object
# 7373
# No.                            7374
# announce_date              1/2/2021
# notification_date          1/1/2021
# sex                             ชาย
# age                              49
# nationality                Thailand
# province_of_isolation      จันทบุรี
# province_of_onset          จันทบุรี
# district_of_onset        เขาคิชฌกูฏ
# risk                            NaN
# Name: 7373, dtype: object
# 7374
# No.                               7375
# announce_date                 1/2/2021
# notification_date             1/1/2021
# sex                               หญิง
# age                                 35
# nationality                   Thailand
# province_of_isolation         จันทบุรี
# province_of_onset             จันทบุรี
# district_of_onset                เมือง
# risk                     Cluster ระยอง
# Name: 7374, dtype: object
# 7375
# No.                          7376
# announce_date            1/2/2021
# notification_date        1/1/2021
# sex                           ชาย
# age                            56
# nationality              Thailand
# province_of_isolation    จันทบุรี
# province_of_onset        จันทบุรี
# district_of_onset         ท่าใหม่
# risk                          NaN
# Name: 7375, dtype: object
# 7376
# No.                               7377
# announce_date                 1/2/2021
# notification_date             1/1/2021
# sex                               หญิง
# age                                 25
# nationality                   Thailand
# province_of_isolation         จันทบุรี
# province_of_onset             จันทบุรี
# district_of_onset        เมืองจันทบุรี
# risk                               NaN
# Name: 7376, dtype: object
# 7377
# No.                          7378
# announce_date            1/2/2021
# notification_date        1/1/2021
# sex                           ชาย
# age                            25
# nationality              Thailand
# province_of_isolation    จันทบุรี
# province_of_onset             NaN
# district_of_onset             NaN
# risk                          NaN
# Name: 7377, dtype: object
# 7378
# No.                          7379
# announce_date            1/2/2021
# notification_date        1/1/2021
# sex                           ชาย
# age                            26
# nationality              Thailand
# province_of_isolation    จันทบุรี
# province_of_onset             NaN
# district_of_onset             NaN
# risk                          NaN
# Name: 7378, dtype: object
# 7384
# No.                                                             7385
# announce_date                                               1/3/2021
# notification_date                                           1/1/2021
# sex                                                             หญิง
# age                                                               33
# nationality                                                 Thailand
# province_of_isolation                                  กรุงเทพมหานคร
# province_of_onset                                      กรุงเทพมหานคร
# district_of_onset                                            หลักสี่
# risk                     สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# Name: 7384, dtype: object
# 7385
# No.                                                             7386
# announce_date                                               1/3/2021
# notification_date                                           1/1/2021
# sex                                                             หญิง
# age                                                               57
# nationality                                                 Thailand
# province_of_isolation                                  กรุงเทพมหานคร
# province_of_onset                                      กรุงเทพมหานคร
# district_of_onset                                           ทวีวัฒนา
# risk                     สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# Name: 7385, dtype: object
